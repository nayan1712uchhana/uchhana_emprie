# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data = df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = df['lat'],y= df['long'],hue = 'price', data=df)

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
 non_top_1_pre = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = df['lat'],y= df['long'],
                edgecolor = None,alpha = 0.4,palette = 'RdYlGn',hue = 'price', data=non_top_1_pre)

# %%
sns.countplot(x = 'condition',data =df)

# %%
df.drop('id',axis = 1,inplace = True)

# %%
 #convert it into date time object by 
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
#extract year from above data
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
sns.boxplot(x='month',y='price',data = df)

# %%
df.groupby('month').mean()['price']
df = df.drop('date',axis =1)
df = df.drop('zipcode',axis =1)
x = df.drop('price',axis= 1).values
y =df['price'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state =101)

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()

# %%
x_train = mm.fit_transform(x_train)

# %%
x_test = mm.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
x_train.shape
# Out:
# (17277, 19)

# %%
model = Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
                 
model.add(Dense(1))
                
model.compile(optimizer='adam' , loss = 'mse' )

# %%
model.fit(x_train,y_train,
          validation_data = (x_test,y_test),batch_size = 128,epochs=400 )
# Out:
# Train on 17277 samples, validate on 4320 samples
# Epoch 1/400
# 17277/17277 [==============================] - 1s 56us/sample - loss: 61339792620.4262 - val_loss: 46606860105.9556
# Epoch 2/400
# 17277/17277 [==============================] - 1s 31us/sample - loss: 50470145563.8863 - val_loss: 40653464765.6296
# Epoch 3/400
# 17277/17277 [==============================] - 0s 26us/sample - loss: 45494318495.0647 - val_loss: 37217273021.6296
# Epoch 4/400
# 17277/17277 [==============================] - 1s 37us/sample - loss: 41957606821.2287 - val_loss: 35015430902.5185
# Epoch 5/400
# 17277/17277 [==============================] - 0s 27us/sample - loss: 39199332794.0323 - val_loss: 33268579077.6889
# Epoch 6/400
# 17277/17277 [==============================] - 1s 31us/sample - loss: 37061734598.5530 - val_loss: 32363177210.3111
# Epoch 7/400
# 17277/17277 [==============================] - 0s 27us/sample - loss: 35709651483.2344 - val_loss: 31761690077.8667
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
predictions = model.predict(x_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 134562.5721260998

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8570216290197996

# %%
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')  #for red line that fitline

# %%
single_house = df.drop('price',axis =1).iloc[0]

# %%
single_house = mm.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[275124.66]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
